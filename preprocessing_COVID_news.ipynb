# %% [markdown]
# <a href="https://colab.research.google.com/github/workhardzy/K6312/blob/main/preprocessing_COVID_news.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading the libraries needed

# %%
#note you need to have it on your own google drive,for those who are sharing a drive, an approach is to add shortcut to your drive. 
#See https://stackoverflow.com/questions/54351852/accessing-shared-with-me-with-colab
#put in your authorisation code that is linked to the google account you are linking to and press enter
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
#open file
import os
#import display
from IPython.display import display

import pandas as pd
import re, pickle, os
import datetime 
import nltk
from nltk.util import ngrams
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords, wordnet 
from collections import Counter 
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models
from gensim.corpora import MmCorpus
from gensim.models.coherencemodel import CoherenceModel
#import pyLDAvis.gensim

import matplotlib.pyplot as plt
# %matplotlib inline
import math
import ast
from tqdm.notebook import tqdm

pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# text preprocessing

# %%
additional_stop_words = ['marketscreener', 'express co']                                                      ########调 (optional)
additional_stop_words = [words.lower() for words in additional_stop_words] #lowercasing the tokens

#classic understanding is to use nouns and verbs. see https://towardsdatascience.com/the-complete-guide-for-topics-extraction-in-python-a6aaa6cedbbc
#ngram ordering also matters when cleaning data


def get_wordnet_pos(word):
    """
    Map POS tag to first character lemmatize() accepts
    """
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"N": wordnet.NOUN,
                "V": wordnet.VERB,
                #"J": wordnet.ADJ, #classic understanding is to use nouns and verbs
                #"R": wordnet.ADV
               }

    return tag_dict.get(tag, wordnet.NOUN)

def text_cleanup(text):  
    '''
    Text pre-processing
        return tokenized list of cleaned words
    '''
    text = str(text)
    # Convert to lowercase
    text_clean = text.lower()
    # Remove non-alphabet
    text_clean = re.sub(r'[^a-zA-Z]|(\w+:\/\/\S+)',' ', text_clean).split()    
    # Remove short words (length < 3)
    #text_clean = [w for w in text_clean if len(w)>2]

    # Lemmatize text with the appropriate POS tag
    lemmatizer = WordNetLemmatizer()
    text_clean = [lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in text_clean]
    # Filter out stop words in English 
    stops = set(stopwords.words('english')).union(additional_stop_words)
    text_clean = [w for w in text_clean if w not in stops]
    #joining the words together to remove bigram stopwords
    text_clean = ' '.join(text_clean)
    #remove bigram stopwords
    for stop in additional_stop_words:
        text_clean = text_clean.replace(stop, "")
    text_clean = text_clean.split()
    
    return text_clean

def preprocess_text(df,txt_col):
    # dataframe to add parsed tweets 
    cleaned_df = df.copy(deep=True)#what is this
    # parsing text 
    cleaned_df['token'] = [text_cleanup(x) for x in df[txt_col]]
    print('Start preprocessing tweets ...\n')
             
    # Save cleaned text to file
    return cleaned_df 

def save_checkpoint(df,filepath):
    df.to_pickle(filepath)
    print('saved dataframe at {}'.format(filepath))

# %%
#testing
text = "China pneumonia outbreak: It's not SARS, so what is it? - CNN MarketScreener Express.co"
text_cleanup(text)
# Out:
# 'china pneumonia outbreak sars cnn '

# %%
#these are the functions to train the model

def save_print_to_file(outfile, msg):
    with open(outfile, 'w') as fp:
        print(msg, file=fp)  

def get_word_count(tweets_text, num_gram):
    '''
    Get common word counts
    '''
    n_grams = list(ngrams(tweets_text, num_gram))
    
    #stop_ngrams = ['local news']
    #n_grams = [i for i in n_grams if i not in stop_ngrams]
    
    common_words = Counter(n_grams).most_common()
    word_count = pd.DataFrame(data = common_words, 
                              columns=['word','frequency']) 
    # Convert list to string
    word_count['word'] = word_count['word'].apply(' '.join)
    # Plot word count graph
    word_count.head(20).sort_values('frequency').plot.barh(
            x='word', y='frequency', title='Word Frequency',figsize=(19,10))
    #plt.savefig(WORD_COUNT_FILE)
    #print ('Word count saved\n')
    #plt.close('all')
    
    return word_count

def word_grams(words, min=1, max=2):
    '''
    Build ngrams word list
    '''
    word_list = []
    for n in range(min, max):
        for ngram in ngrams(words, n):
            #print(ngram)
            word_list.append(' '.join(str(i) for i in ngram)) 
    return word_list

def train_lda_model(token_tweets):
    print('Start LDA model training ...\n')    
    # Build dictionary
    print('building dictionary')
    tweets_dict = corpora.Dictionary(token_tweets)
    # Remove words that occur less than 10 documents, # or more than 50% of the doc
    tweets_dict.filter_extremes(no_below=10, no_above=0.5)                       ########调
    # Transform doc to a vectorized form by computing frequency of each word
    bow_corpus = [tweets_dict.doc2bow(doc) for doc in token_tweets]
    # Save corpus and dictionary to file
    MmCorpus.serialize(CORPUS_FILE, bow_corpus)
    tweets_dict.save(DICT_FILE)
    print('saved corpus and dictionary to file')
    
    # Create tf-idf model and then apply transformation to the entire corpus
    print('create tf-idf model')
    tfidf = models.TfidfModel(bow_corpus)                                       ########调 (optional)
    tfidf_corpus = tfidf[bow_corpus]                                            ########调 (optional)
    
    print('training lda')
    # Train LDA model #this is the time bottleneck
    lda_model = models.ldamodel.LdaModel(corpus=tfidf_corpus,                   ########调 (optional)
                                         num_topics=NUM_TOPICS, 
                                         id2word=tweets_dict, 
                                         passes=NUM_PASSES, 
                                         alpha=ALPHA, 
                                         eta=ETA,
                                         random_state=42)
    # Save LDA model to file
    lda_model.save(LDA_MODEL_FILE)
    print ('LDA model saved\n')
      
    # Save all generated topics to a file
    msg = ''
    for idx, topic in lda_model.print_topics(-1):
        msg += 'Topic: {} \nWords: {}\n'.format(idx, topic)    
    save_print_to_file(LDA_TOPICS_FILE, msg)
    
    # Evaluate LDA model performance
    eval_lda (lda_model, tfidf_corpus, tweets_dict, token_tweets)    
    # Visualize topics
    vis_topics(lda_model, tfidf_corpus, tweets_dict)
        
    return lda_model

def eval_lda (lda_model, corpus, dict, token_text):
    
    # Compute Perplexity: a measure of how good the model is. lower the better.
    print('\nPerplexity: ', lda_model.log_perplexity(corpus))  
    
    # Compute Coherence Score
    coherence_model_lda = CoherenceModel(model=lda_model, texts=token_text, 
                                         dictionary=dict, coherence='c_v')   
    print('\nCoherence: ', coherence_model_lda.get_coherence())

def vis_topics(lda_model, corpus, dict):
    '''
    Plot generated topics on an interactive graph
    '''
    lda_data =  pyLDAvis.gensim.prepare(lda_model, corpus, dict, mds='mmds')
    pyLDAvis.display(lda_data)
    pyLDAvis.save_html(lda_data, TOPIC_VIS_FILE)
    print ('Topic visual saved\n')

def wordcloud(word_count_df):
    '''
    Create word cloud image
    '''
    # Convert DataFrame to Map so that word cloud can be generated from freq
    word_count_dict = {}
    for w, f in word_count_df.values:
        word_count_dict[w] = f
    # Generate word cloud 
    wordcloud = WordCloud(max_words=300, width=1400, height=900, 
                          random_state=12, contour_width=3, 
                          contour_color='firebrick')
    wordcloud.generate_from_frequencies(word_count_dict)
    plt.figure(figsize=(10,10), facecolor='k')
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    # Save the word cloud image
    #wordcloud.to_file(WORDCLOUD_FILE) 
    #print ('Word cloud saved\n')
    #plt.close('all')
    
    return wordcloud

# %%
def clean_topics(df,col):
    print('CLEANING...')
    cleaned_tweets_df = preprocess_text(df,col) ########调
    return cleaned_tweets_df
    
def generate_ngrams(cleaned_tweets_df,NUM_GRAMS):
    # Convert series to list for word count
    print('creating tweets_text corpus')
    tweets_text = [word for one_tweet in cleaned_tweets_df['token'] for word in one_tweet]
    
    print('getting ngram word count')
    # Get common ngrams word count
    word_count_df = get_word_count(tweets_text, num_gram=NUM_GRAMS)
    
    # Generate word cloud
    tweets_wordcloud = wordcloud(word_count_df)  

    # Generate ngram tokens
    cleaned_tweets_df['ngram_token'] = [word_grams(x, NUM_GRAMS, NUM_GRAMS+1) for x in cleaned_tweets_df['token']]
    
    #cleaned_tweets_df.to_pickle('gdrive/My Drive/IO - twitter datasets/russia/preprocessed_IRA2016.h5')
    
    return cleaned_tweets_df

    
def trainingLDA(ngrams):
    print('TRAINING...')
    # Train LDA model and visualize generated topics
    lda_model = train_lda_model(ngrams)

    print('DONE!')
    
    return lda_model

# %% [markdown]
# Here we start training the model and the data

# %% [markdown]
# #can skip this part if text preprocessing is done
# 因为这个部分花很多时间
#
# We have chosen to limit our analysis to news headlines

# %%
lst = [
       #'/content/gdrive/My Drive/covid_mining/covid19_articles.csv',
       #'/content/gdrive/My Drive/covid_mining/covid19_articles_20200504.csv',
       #'/content/gdrive/My Drive/covid_mining/covid19_articles_20200512.csv',
       #'/content/gdrive/My Drive/covid_mining/covid19_articles_20200526.csv',
       #'/content/gdrive/My Drive/covid_mining/covid19_articles_20200726.csv',
       '/content/gdrive/My Drive/covid_mining/covid19_articles_20200914.csv'
       ]

def concat_csv(lst):
    cncat = []
    for i in tqdm(range(len(lst))):
        df = pd.read_csv(lst[i],encoding='utf-8')
        #df = df.drop(['Unnamed: 0', 'author', 'domain', 'url','crawled_time'],axis=1).drop_duplicates()
        cncat.append(df)
    
    df = pd.concat(cncat)
    return df.drop(['Unnamed: 0', 'author', 'domain', 'url','crawled_time','content'],axis=1).drop_duplicates()
     

# %time df = concat_csv(lst)
df
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# CPU times: user 24.7 s, sys: 2.17 s, total: 26.9 s
# Wall time: 32.1 s
#                                                                                            title  ... topic_area
# 0       Three Industrial Giants You Should Own In 2020                                            ...  business
# 1       Tesla (TSLA) Breaks Shipment Record, Beats Estimates for Fourth Quarter Vehicles Shipped  ...  business
# 2       Labor Stocks Are Going To Break Out In 2020                                               ...  business
# 3       Cal-Maine Just Shed 12% - But Is Now The Time To Buy                                      ...  business
# 4       China pneumonia outbreak: It's not SARS, so what is it? - CNN                             ...  business
# ...                                                               ...                             ...       ...
# 290474  Trump signs new, expanded executive order to lower U.S. drug prices                       ...  business
# 290475  Nuggets force Game 7 and D'Antoni leaves HOU                                              ...  business
# 290476  Health Official Out To Manipulate CDC Reports Has Deep Russian Ties                       ...  business
# 290477  Global Markets: Asian shares buoyed by coronavirus vaccine hopes                          ...  business
# 290478  Japan’s Suga Wins Ruling Party Race to Replace Premier Abe                                ...  business
#
# [288808 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['title', 'date', 'topic_area'], dtype='object')

# %%
pd.set_option('display.max_colwidth', -1)
#df['text'] = df['title'] + ' '+  df['content']
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
#                                                                                            title  ... topic_area
# 0       Three Industrial Giants You Should Own In 2020                                            ...  business
# 1       Tesla (TSLA) Breaks Shipment Record, Beats Estimates for Fourth Quarter Vehicles Shipped  ...  business
# 2       Labor Stocks Are Going To Break Out In 2020                                               ...  business
# 3       Cal-Maine Just Shed 12% - But Is Now The Time To Buy                                      ...  business
# 4       China pneumonia outbreak: It's not SARS, so what is it? - CNN                             ...  business
# ...                                                               ...                             ...       ...
# 290474  Trump signs new, expanded executive order to lower U.S. drug prices                       ...  business
# 290475  Nuggets force Game 7 and D'Antoni leaves HOU                                              ...  business
# 290476  Health Official Out To Manipulate CDC Reports Has Deep Russian Ties                       ...  business
# 290477  Global Markets: Asian shares buoyed by coronavirus vaccine hopes                          ...  business
# 290478  Japan’s Suga Wins Ruling Party Race to Replace Premier Abe                                ...  business
#
# [288808 rows x 3 columns]

# %%
#text preprocessing and ngrams generation
# %time df = clean_topics(df,'title') #this takes a long time, if there is the preprocessed_news.h5 file, use that
save_checkpoint(df,'/content/gdrive/My Drive/covid_mining/preprocessed_news_headlines.h5') ########调
# Out:
# CLEANING...
# Start preprocessing tweets ...
#
# CPU times: user 8min 8s, sys: 27.7 s, total: 8min 35s
# Wall time: 8min 36s
# saved dataframe at /content/gdrive/My Drive/covid_mining/preprocessed_news_headlines.h5

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

df = pd.read_pickle('/content/gdrive/My Drive/covid_mining/preprocessed_news_headlines.h5') ########调
df = generate_ngrams(df,NUM_GRAMS=2) #NUM_GRAMS is bad convention, but I am not changing it due to practical reasons
df
# Out:
# creating tweets_text corpus
# getting ngram word count
#                                                                                            title  ...                                                                                                                                            ngram_token
# 0       Three Industrial Giants You Should Own In 2020                                            ...  [three industrial, industrial giant]
# 1       Tesla (TSLA) Breaks Shipment Record, Beats Estimates for Fourth Quarter Vehicles Shipped  ...  [tesla tsla, tsla break, break shipment, shipment record, record beat, beat estimate, estimate fourth, fourth quarter, quarter vehicle, vehicle ship]
# 2       Labor Stocks Are Going To Break Out In 2020                                               ...  [labor stock, stock go, go break]
# 3       Cal-Maine Just Shed 12% - But Is Now The Time To Buy                                      ...  [cal maine, maine shed, shed time, time buy]
# 4       China pneumonia outbreak: It's not SARS, so what is it? - CNN                             ...  [china pneumonia, pneumonia outbreak, outbreak sars, sars cnn]
# ...                                                               ...                             ...                                                             ...
# 290474  Trump signs new, expanded executive order to lower U.S. drug prices                       ...  [trump sign, sign new, new expand, expand executive, executive order, order lower, lower u, u drug, drug price]
# 290475  Nuggets force Game 7 and D'Antoni leaves HOU                                              ...  [nugget force, force game, game antoni, antoni leaf, leaf hou]
# 290476  Health Official Out To Manipulate CDC Reports Has Deep Russian Ties                       ...  [health official, official manipulate, manipulate cdc, cdc report, report deep, deep russian, russian tie]
# 290477  Global Markets: Asian shares buoyed by coronavirus vaccine hopes                          ...  [global market, market asian, asian share, share buoyed, buoyed coronavirus, coronavirus vaccine, vaccine hope]
# 290478  Japan’s Suga Wins Ruling Party Race to Replace Premier Abe                                ...  [japan suga, suga win, win ruling, ruling party, party race, race replace, replace premier, premier abe]
#
# [288808 rows x 5 columns]

# %%
df
# Out:
#                                                                                            title  ...                                                                                                                                            ngram_token
# 0       Three Industrial Giants You Should Own In 2020                                            ...  [three industrial, industrial giant]
# 1       Tesla (TSLA) Breaks Shipment Record, Beats Estimates for Fourth Quarter Vehicles Shipped  ...  [tesla tsla, tsla break, break shipment, shipment record, record beat, beat estimate, estimate fourth, fourth quarter, quarter vehicle, vehicle ship]
# 2       Labor Stocks Are Going To Break Out In 2020                                               ...  [labor stock, stock go, go break]
# 3       Cal-Maine Just Shed 12% - But Is Now The Time To Buy                                      ...  [cal maine, maine shed, shed time, time buy]
# 4       China pneumonia outbreak: It's not SARS, so what is it? - CNN                             ...  [china pneumonia, pneumonia outbreak, outbreak sars, sars cnn]
# ...                                                               ...                             ...                                                             ...
# 290474  Trump signs new, expanded executive order to lower U.S. drug prices                       ...  [trump sign, sign new, new expand, expand executive, executive order, order lower, lower u, u drug, drug price]
# 290475  Nuggets force Game 7 and D'Antoni leaves HOU                                              ...  [nugget force, force game, game antoni, antoni leaf, leaf hou]
# 290476  Health Official Out To Manipulate CDC Reports Has Deep Russian Ties                       ...  [health official, official manipulate, manipulate cdc, cdc report, report deep, deep russian, russian tie]
# 290477  Global Markets: Asian shares buoyed by coronavirus vaccine hopes                          ...  [global market, market asian, asian share, share buoyed, buoyed coronavirus, coronavirus vaccine, vaccine hope]
# 290478  Japan’s Suga Wins Ruling Party Race to Replace Premier Abe                                ...  [japan suga, suga win, win ruling, ruling party, party race, race replace, replace premier, premier abe]
#
# [288808 rows x 5 columns]

# %%
save_checkpoint(df,'/content/gdrive/My Drive/covid_mining/preprocessed_news_headlines.h5') ########调
# Out:
# saved dataframe at /content/gdrive/My Drive/covid_mining/preprocessed_news_headlines.h5

# %%
#run this when you want to skip preprocessing
df = pd.read_pickle('/content/gdrive/My Drive/covid_mining/preprocessed_news_headlines.h5') ########调 
df
# Out:
#                                                                                            title  ...                                                                                                                                            ngram_token
# 0       Three Industrial Giants You Should Own In 2020                                            ...  [three industrial, industrial giant]
# 1       Tesla (TSLA) Breaks Shipment Record, Beats Estimates for Fourth Quarter Vehicles Shipped  ...  [tesla tsla, tsla break, break shipment, shipment record, record beat, beat estimate, estimate fourth, fourth quarter, quarter vehicle, vehicle ship]
# 2       Labor Stocks Are Going To Break Out In 2020                                               ...  [labor stock, stock go, go break]
# 3       Cal-Maine Just Shed 12% - But Is Now The Time To Buy                                      ...  [cal maine, maine shed, shed time, time buy]
# 4       China pneumonia outbreak: It's not SARS, so what is it? - CNN                             ...  [china pneumonia, pneumonia outbreak, outbreak sars, sars cnn]
# ...                                                               ...                             ...                                                             ...
# 290474  Trump signs new, expanded executive order to lower U.S. drug prices                       ...  [trump sign, sign new, new expand, expand executive, executive order, order lower, lower u, u drug, drug price]
# 290475  Nuggets force Game 7 and D'Antoni leaves HOU                                              ...  [nugget force, force game, game antoni, antoni leaf, leaf hou]
# 290476  Health Official Out To Manipulate CDC Reports Has Deep Russian Ties                       ...  [health official, official manipulate, manipulate cdc, cdc report, report deep, deep russian, russian tie]
# 290477  Global Markets: Asian shares buoyed by coronavirus vaccine hopes                          ...  [global market, market asian, asian share, share buoyed, buoyed coronavirus, coronavirus vaccine, vaccine hope]
# 290478  Japan’s Suga Wins Ruling Party Race to Replace Premier Abe                                ...  [japan suga, suga win, win ruling, ruling party, party race, race replace, replace premier, premier abe]
#
# [288808 rows x 5 columns]

# %%
#check if the word is in the title
df[df['title'].str.contains('MarketScreener')]
# Out:
#                                                                                                                                      title  ...                                                                                                                                                                                            ngram_token
# 62      Southeast Asia stocks: Singapore falls on China virus fears, Philippines extends losses | MarketScreener                            ...  [southeast asia, asia stock, stock singapore, singapore fall, fall china, china virus, virus fear, fear philippine, philippine extends, extends loss, loss marketscreener]
# 90      Virus outbreak prompts Chinese travel firms to offer free cancellations | MarketScreener                                            ...  [virus outbreak, outbreak prompt, prompt chinese, chinese travel, travel firm, firm offer, offer free, free cancellation, cancellation marketscreener]
# 92      China Eastern Airlines Down Over 10%, on Pace for Largest Percent Decrease Since August 2015 -- Data Talk | MarketScreener          ...  [china eastern, eastern airline, airline pace, pace largest, largest percent, percent decrease, decrease since, since august, august data, data talk, talk marketscreener]
# 115     European Luxury, Airline Stocks Suffer Blow Amid Chinese Outbreak -- 2nd Update | MarketScreener                                    ...  [european luxury, luxury airline, airline stock, stock suffer, suffer blow, blow amid, amid chinese, chinese outbreak, outbreak nd, nd update, update marketscreener]
# 134     China virus scare sends shudder through European luxury goods sector | MarketScreener                                               ...  [china virus, virus scare, scare sends, sends shudder, shudder european, european luxury, luxury good, good sector, sector marketscreener]
# ...                                                                                       ...                                               ...                                                                                                                                         ...
# 290331  Pound dogged by Brexit worries, yen looks to Abe successor vote | MarketScreener                                                    ...  [pound dog, dog brexit, brexit worry, worry yen, yen look, look abe, abe successor, successor vote, vote marketscreener]
# 290332  AFC : Director nominations & virtual-only 2020 AGM date | MarketScreener                                                            ...  [afc director, director nomination, nomination virtual, virtual agm, agm date, date marketscreener]
# 290333  Bidvest : 14th September 2020 - Bidvest FY20 results; Chief Executive retirement and appointment | MarketScreener                   ...  [bidvest th, th september, september bidvest, bidvest fy, fy result, result chief, chief executive, executive retirement, retirement appointment, appointment marketscreener]
# 290335  Portfolio Company Update: Guident | MarketScreener                                                                                  ...  [portfolio company, company update, update guident, guident marketscreener]
# 290336  Mitsui Chemicals : rsquo; UNISTOLE™ Adopted by Siemens as Coating Agent for 3D-Printed Medical-Grade Face Shields | MarketScreener  ...  [mitsui chemical, chemical rsquo, rsquo unistole, unistole adopt, adopt siemens, siemens coat, coat agent, agent print, print medical, medical grade, grade face, face shield, shield marketscreener]
#
# [48326 rows x 5 columns]

# %% [markdown]
# #to cut the data by month

# %%
df = pd.read_pickle('/content/gdrive/My Drive/covid_mining/preprocessed_news_headlines.h5') ########调 
df
# Out:
#                                                                                            title  ...                                                                                                                                            ngram_token
# 0       Three Industrial Giants You Should Own In 2020                                            ...  [three industrial, industrial giant]
# 1       Tesla (TSLA) Breaks Shipment Record, Beats Estimates for Fourth Quarter Vehicles Shipped  ...  [tesla tsla, tsla break, break shipment, shipment record, record beat, beat estimate, estimate fourth, fourth quarter, quarter vehicle, vehicle ship]
# 2       Labor Stocks Are Going To Break Out In 2020                                               ...  [labor stock, stock go, go break]
# 3       Cal-Maine Just Shed 12% - But Is Now The Time To Buy                                      ...  [cal maine, maine shed, shed time, time buy]
# 4       China pneumonia outbreak: It's not SARS, so what is it? - CNN                             ...  [china pneumonia, pneumonia outbreak, outbreak sars, sars cnn]
# ...                                                               ...                             ...                                                             ...
# 290474  Trump signs new, expanded executive order to lower U.S. drug prices                       ...  [trump sign, sign new, new expand, expand executive, executive order, order lower, lower u, u drug, drug price]
# 290475  Nuggets force Game 7 and D'Antoni leaves HOU                                              ...  [nugget force, force game, game antoni, antoni leaf, leaf hou]
# 290476  Health Official Out To Manipulate CDC Reports Has Deep Russian Ties                       ...  [health official, official manipulate, manipulate cdc, cdc report, report deep, deep russian, russian tie]
# 290477  Global Markets: Asian shares buoyed by coronavirus vaccine hopes                          ...  [global market, market asian, asian share, share buoyed, buoyed coronavirus, coronavirus vaccine, vaccine hope]
# 290478  Japan’s Suga Wins Ruling Party Race to Replace Premier Abe                                ...  [japan suga, suga win, win ruling, ruling party, party race, race replace, replace premier, premier abe]
#
# [288808 rows x 5 columns]

# %%
#df['date'] = df['date'].to_datetime()

df.date = pd.to_datetime(df.date)

# %%
df['month'] = df['date'].dt.month

# %%
df
# Out:
#                                                                                            title  ... month
# 0       Three Industrial Giants You Should Own In 2020                                            ...  1
# 1       Tesla (TSLA) Breaks Shipment Record, Beats Estimates for Fourth Quarter Vehicles Shipped  ...  1
# 2       Labor Stocks Are Going To Break Out In 2020                                               ...  1
# 3       Cal-Maine Just Shed 12% - But Is Now The Time To Buy                                      ...  1
# 4       China pneumonia outbreak: It's not SARS, so what is it? - CNN                             ...  1
# ...                                                               ...                             ... ..
# 290474  Trump signs new, expanded executive order to lower U.S. drug prices                       ...  9
# 290475  Nuggets force Game 7 and D'Antoni leaves HOU                                              ...  9
# 290476  Health Official Out To Manipulate CDC Reports Has Deep Russian Ties                       ...  9
# 290477  Global Markets: Asian shares buoyed by coronavirus vaccine hopes                          ...  9
# 290478  Japan’s Suga Wins Ruling Party Race to Replace Premier Abe                                ...  9
#
# [288808 rows x 6 columns]

# %%
max(df['month'])
# Out:
# 9

# %%
for i in range(max(df['month'])+1):
    display(df[df['month']==i])
    _ = df[df['month']==i]

    save_checkpoint(_,'/content/gdrive/My Drive/covid_mining/preprocessed_news_headlines{}.h5'.format(i)) ########调
# Out:
# Empty DataFrame
# Columns: [title, date, topic_area, token, ngram_token, month]
# Index: []
# saved dataframe at /content/gdrive/My Drive/covid_mining/preprocessed_news_headlines0.h5
#                                                                                                  title  ... month
# 0     Three Industrial Giants You Should Own In 2020                                                    ...  1
# 1     Tesla (TSLA) Breaks Shipment Record, Beats Estimates for Fourth Quarter Vehicles Shipped          ...  1
# 2     Labor Stocks Are Going To Break Out In 2020                                                       ...  1
# 3     Cal-Maine Just Shed 12% - But Is Now The Time To Buy                                              ...  1
# 4     China pneumonia outbreak: It's not SARS, so what is it? - CNN                                     ...  1
# ...                                                             ...                                     ... ..
# 1948  Fake coronavirus cures and other misinformation taken down by Facebook, Google and Twitter - CNN  ...  1
# 1949  Travel ban expanded to six new countries - CNNPolitics                                            ...  1
# 1950  Goldman Sachs warns that the coronavirus could slow the US economy - CNN                          ...  1
# 1951  Jim Carrey health latest: Actor discusses depression - symptoms and signs  | Express.co.uk        ...  1
# 1952  The coronavirus could cost China's economy $60 billion this quarter.  - CNN                       ...  1
#
# [1953 rows x 6 columns]
# saved dataframe at /content/gdrive/My Drive/covid_mining/preprocessed_news_headl
rows x 6 columns]
# saved dataframe at /content/gdrive/My Drive/covid_mining/preprocessed_news_headlines6.h5
#                                                                                                                                       title  ... month
# 175531  Office Depot's Stock Just Jumped -- But You Won't Like the Reason Why | The Motley Fool                                              ...  7
# 175532  Square, Wayfair Ride the Stock Market's E-Commerce Wave Higher | The Motley Fool                                                     ...  7
# 175533  European stocks log modest gains as the quarter kicks off, boosted by China data - MarketWatch                                       ...  7
# 175534  Is Qualcomm Stock a Buy? | The Motley Fool                                                                                           ...  7
# 175535  Elon Musk Stays True to His Word: Tesla Raises Full Self-Driving Price to $8,000 | The Motley Fool                                   ...  7
# ...                                                                                                    ...                                   ... ..
# 243290  Shell Posts Loss of $18.4 Billion -- WSJ | MarketScreener                                                                            ...  7
# 243291  Equity Metals : Third Quarter Report - Jul 30, 2020 | MarketScreener                                                                 ...  7
# 243292  Taylor Wimpey : Half year 2020 transcript | MarketScreener                                                                           ...  7
# 243293  Capital Product Partners L P : Second Quarter 2020 Financial Results Conference Call | MarketScreener                                ...  7
# 243294  Takeda Pharmaceutical Company Limited: Notice of the Revised Forecast of Consolidated Financials for FY2020 (IFRS) | MarketScreener  ...  7
#
# [66953 rows x 6 columns]
# saved dataframe at /content/gdrive/My Drive/covid_mining/preprocessed_news_headlines7.h5
#                                                                                                                                                     title  ... month
# 243295  Grifols : 2020 first half consolidated interim financial statements | MarketScreener                                                               ...  8
# 243296  Pharming N : Group reports financial results for the first half of 2020 | MarketScreener                                                           ...  8
# 243297  Southwest Airlines : Airlines, unions pin hopes for more payroll cash on politics | MarketScreener                                                 ...  8
# 243298  LATAM Airlines S A : set to fire at least 2,700 workers in Brazil | MarketScreener                                                                 ...  8
# 243299  Ionic Rare Earths : QUARTERLY REPORT FOR THE PERIOD ENDING 30 JUNE 2020                                                                            ...  8
# ...                                                                         ...                                                                            ... ..
# 273932  10 ways to avoid a penalty for taking an early retirement-account withdrawal because of COVID-19 - MarketWatch                                     ...  8
# 273933  'Abenomics' May Stay, but Japan's Economic Overhaul Is Incomplete                                                                                  ...  8
# 273934  2020 MTV VMAs: Lady Gaga's Masks Were the Winners                                                                                                  ...  8
# 273935  Bill Ackman on saving capitalism: Every child in the U.S. could be given enough money at birth to become millionaires by retirement - MarketWatch  ...  8
# 273936  España vive una segunda ola de coronavirus                                                                                                         ...  8
#
# [30409 rows x 6 columns]
# saved dataframe at /content/gdrive/My Drive/covid_mining/preprocessed_news_headlines8.h5
#                                                                                               title  ... month
# 273937  Samsung eyes new opportunities as pandemic ignites demand for home appliances                ...  9
# 273938  Horse racing: Tiz the Law arrives, Art Collector exits at Churchill Downs                    ...  9
# 273939  US Open 2020: Osaka passes Doi test and Pliskova advances but Gauff falls                    ...  9
# 273940  The future of sports TV coverage? Eurosport unveils mixed-reality 'Cube' studio for US Open  ...  9
# 273941  U.S. employment projected to increase six million from 2019 to 2029: Labor Department        ...  9
# ...                                                                                       ...        ... ..
# 290474  Trump signs new, expanded executive order to lower U.S. drug prices                          ...  9
# 290475  Nuggets force Game 7 and D'Antoni leaves HOU                                                 ...  9
# 290476  Health Official Out To Manipulate CDC Reports Has Deep Russian Ties                          ...  9
# 290477  Global Markets: Asian shares buoyed by coronavirus vaccine hopes                             ...  9
# 290478  Japan’s Suga Wins Ruling Party Race to Replace Premier Abe                                   ...  9
#
# [16301 rows x 6 columns]
# saved dataframe at /content/gdrive/My Drive/covid_mining/preprocessed_news_headlines9.h5
